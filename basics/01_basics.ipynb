# %% [markdown]
# # Print and input

# %%
import os

for folder in ["data", "notebooks", "src", "outputs"]:
    os.makedirs(folder, exist_ok=True)

print("Folders created")
# Out:
# Folders created

# %% [markdown]
# ### Working with variables

# %%
print("hello world")
# Out:
# hello world

# %%
print("Prof Shai")
# Out:
# Prof Shai

# %%
print("1. Mix 500g of Flour, 10g Yeast and 300ml Water in a bowl.\n2. Knead the dough for 10 minutes.\n3. This is awesome")
# Out:
# 1. Mix 500g of Flour, 10g Yeast and 300ml Water in a bowl.
# 2. Knead the dough for 10 minutes.
# 3. This is awesome

# %%
print("Hello" + " Shai")
# Out:
# Hello Shai

# %%
input("How are you doing")
# Out:
# How are you doing I'm good
# "I'm good"

# %%
print("Hello " + input("What is your name?"))
# Out:
# What is your name? Shai
# Hello Shai

# %%
print("Hello " + input("What is your name?") + "!")
# Out:
# What is your name? Shai
# Hello Shai!

# %%
name = input("What is your name?")
# Out:
# What is your name? Shai

# %%
print(name)
# Out:
# Shai

# %%
name = "Prof"
print(name)
# Out:
# Prof

# %%
name = input("What is your name?")
print(len(name))
# Out:
# What is your name? shaibu
# 6

# %%
print(len(input("What is your name?")))
# Out:
# What is your name? King Shaibu
# 11

# %%
username = input("What is your username?")
length = len(username)
print(length)
# print(len(input("What is your username?")))
# Out:
# What is your username? sHAIBU
# 6

# %%
#switching contents of the variables
glass1 = "milk"
glass2 = "juice"
glass = glass1
glass1 = glass2
glass2 = glass

print(glass1)
print(glass2)
# Out:
# juice
# milk

# %% [markdown]
# ### Python Keywords
#
# - These are special, reserved words that convey a special meaning to the interpreter or compiler.
# - It is not recommended to use them as a variable in Python.
# - They include: def, else, if, class, continue, break, finally, lambda, import, except, None

# %% [markdown]
# ### DAY 1 PROJECT

# %%
print("Welcome to the Band Name Generator.\n")
city = input("What's the name of the city you grew up in?\n")
pet_name = input("What's your pet's name?\n")
print("Your band name could be " + city + " " + pet_name)
# Out:
# Welcome to the Band Name Generator.
# What's the name of the city you grew up in?
#  Cape
# What's your pet's name?
#  King
# Your band name could be Cape King
